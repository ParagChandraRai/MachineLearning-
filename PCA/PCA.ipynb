# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Given samples
samples = np.array([[2.5, 2.6], [0.5, 0.6], [2.6, 2.9], [3.1, 3.6],[2.3,2.7],[2,1.8],[1.5,1.9],[1.9,2.2],[1.1,0.9],[2.2,2.6]])

# Apply PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(samples)

# Display the results
print("Original Samples:")
print(samples)
print("\nPCA Result:")
print(pca_result)

# Plot the original and PCA-transformed samples
plt.figure(figsize=(8, 4))

# Original samples
plt.subplot(1, 2, 1)
plt.scatter(samples[:, 0], samples[:, 1], c='blue', label='Original Samples')
plt.title('Original Samples')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()

# PCA-transformed samples
plt.subplot(1, 2, 2)
plt.scatter(pca_result[:, 0], pca_result[:, 1], c='red', label='PCA Result')
plt.title('PCA Result')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Original Samples:
# [[2.5 2.6]
#  [0.5 0.6]
#  [2.6 2.9]
#  [3.1 3.6]
#  [2.3 2.7]
#  [2.  1.8]
#  [1.5 1.9]
#  [1.9 2.2]
#  [1.1 0.9]
#  [2.2 2.6]]
#
# PCA Result:
# [[-0.66185813  0.1387221 ]
#  [ 2.1547815  -0.11923373]
#  [-0.95641988  0.0236857 ]
#  [-1.81430956 -0.03975953]
#  [-0.61078882 -0.07897477]
#  [ 0.27289644  0.26613443]
#  [ 0.51586703 -0.1821571 ]
#  [ 0.02940399 -0.06659884]
#  [ 1.54038427  0.1500543 ]
#  [-0.46995684 -0.09187256]]

# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Given samples
samples = np.array([[2, 3, 5], [4, 7, 1], [8, 2, 5], [5, 6, 9]])

# Apply PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(samples)

# Display the results
print("Original Samples:")
print(samples)
print("\nPCA Result:")
print(pca_result)

# Plot the original and PCA-transformed samples
plt.figure(figsize=(8, 4))

# Original samples
plt.subplot(1, 2, 1)
plt.scatter(samples[:, 0], samples[:, 1], c='blue', label='Original Samples')
plt.title('Original Samples')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()

# PCA-transformed samples
plt.subplot(1, 2, 2)
plt.scatter(pca_result[:, 0], pca_result[:, 1], c='red', label='PCA Result')
plt.title('PCA Result')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Original Samples:
# [[2 3 5]
#  [4 7 1]
#  [8 2 5]
#  [5 6 9]]
#
# PCA Result:
# [[ 0.44497649 -1.07077147]
#  [ 4.58248962 -0.15493502]
#  [-1.81641245  3.6728196 ]
#  [-3.21105366 -2.44711311]]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given samples
samples = np.array([[4, 11], [8, 4], [13, 5], [7, 14]])

# Step 1: Center the data
mean_vec = np.mean(samples, axis=0)
centered_samples = samples - mean_vec

# Step 2: Calculate the covariance matrix
cov_matrix = np.cov(centered_samples, rowvar=False)

# Step 3: Obtain eigenvectors and eigenvalues
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# Step 4: Sort eigenvectors by eigenvalues (descending order)
sorted_indices = np.argsort(eigenvalues)[::-1]
eigenvectors = eigenvectors[:, sorted_indices]

# Step 5: Project the data onto the principal components
pca_result = np.dot(centered_samples, eigenvectors)

# Display the results
print("Original Samples:")
print(samples)
print("\nPCA Result:")
print(pca_result)

# Plot the original and PCA-transformed samples
plt.figure(figsize=(8, 4))

# Original samples
plt.subplot(1, 2, 1)
plt.scatter(samples[:, 0], samples[:, 1], c='blue', label='Original Samples')
plt.title('Original Samples')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()

# PCA-transformed samples
plt.subplot(1, 2, 2)
plt.scatter(pca_result[:, 0], pca_result[:, 1], c='red', label='PCA Result')
plt.title('PCA Result')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Original Samples:
# [[ 4 11]
#  [ 8  4]
#  [13  5]
#  [ 7 14]]
#
# PCA Result:
# [[-4.30518692  1.92752836]
#  [ 3.73612869  2.50825486]
#  [ 5.69282771 -2.20038921]
#  [-5.12376947 -2.23539401]]
