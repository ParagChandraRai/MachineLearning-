# %% [markdown]
# <font color='red' size='5'> Problem 1. Basketball (Dataset 4)</font>
#
# **The following data (X1, X2, X3, X4, X5) are for each player.**
#
# **X1 = height in feet**
#
# **X2 = weight in pounds**
#
# **X3 = percent of successful field goals (out of 100 attempted)**
#
# **X4 = percent of successful free throws (out of 100 attempted)**
#
# **X5 = average points scored per game**

# %%
import pandas as pd
df = pd.read_excel('DS4.xls', engine='xlrd')
print (df)
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'iso-8859-1'
#      X1   X2     X3     X4    X5
# 0   6.8  225  0.442  0.672   9.2
# 1   6.3  180  0.435  0.797  11.7
# 2   6.4  190  0.456  0.761  15.8
# 3   6.2  180  0.416  0.651   8.6
# 4   6.9  205  0.449  0.900  23.2
# 5   6.4  225  0.431  0.780  27.4
# 6   6.3  185  0.487  0.771   9.3
# 7   6.8  235  0.469  0.750  16.0
# 8   6.9  235  0.435  0.818   4.7
# 9   6.7  210  0.480  0.825  12.5
# 10  6.9  245  0.516  0.632  20.1
# 11  6.9  245  0.493  0.757   9.1
# 12  6.3  185  0.374  0.709   8.1
# 13  6.1  185  0.424  0.782   8.6
# 14  6.2  180  0.441  0.775  20.3
# 15  6.8  220  0.503  0.880  25.0
# 16  6.5  194  0.503  0.833  19.2
# 17  7.6  225  0.425  0.571   3.3
# 18  6.3  210  0.371  0.816  11.2
# 19  7.1  240  0.504  0.714  10.5
# 20  6.8  225  0.400  0.765  10.1
# 21  7.3  263  0.482  0.655   7.2
# 22  6.4  210  0.475  0.244  13.6
# 23  6.8  235  0.428  0.728   9.0
# 24  7.2  230  0.559  0.721  24.6
# 25  6.4  190  0.441  0.757  12.6
# 26  6.6  220  0.492  0.747   5.6
# 27  6.8  210  0.402  0.739   8.7
# 28  6.1  180  0.415  0.713   7.7
# 29  6.5  235  0.492  0.742  24.1
# 30  6.4  185  0.484  0.861  11.7
# 31  6.0  175  0.387  0.721   7.7
# 32  6.0  192  0.436  0.785   9.6
# 33  7.3  263  0.482  0.655   7.2
# 34  6.1  180  0.340  0.821  12.3
# 35  6.7  240  0.516  0.728   8.9
# 36  6.4  210  0.475  0.846  13.6
# 37  5.8  160  0.412  0.813  11.2
# 38  6.9  230  0.411  0.595   2.8
# 39  7.0  245  0.407  0.573   3.2
# 40  7.3  228  0.445  0.726   9.4
# 41  5.9  155  0.291  0.707  11.9
# 42  6.2  200  0.449  0.804  15.4
# 43  6.8  235  0.546  0.784   7.4
# 44  7.0  235  0.480  0.744  18.9
# 45  5.9  105  0.359  0.839   7.9
# 46  6.1  180  0.528  0.790  12.2
# 47  5.7  185  0.352  0.701  11.0
# 48  7.1  245  0.414  0.778   2.8
# 49  5.8  180  0.425  0.872  11.8
# 50  7.4  240  0.599  0.713  17.1
# 51  6.8  225  0.482  0.701  11.6
# 52  6.8  215  0.457  0.734   5.8
# 53  7.0  230  0.435  0.764   8.3

# %%
df.shape
# Out:
# (54, 5)

# %%
df.X1.skew()
# Out:
# 0.024564869519998166

# %%
df.X2.skew()
# Out:
# -0.7631446477113488

# %%
df.X3.skew()
# Out:
# -0.09900099630192509

# %%
df.X4.skew()
# Out:
# -2.4168411435172423

# %%
df.X5.skew()
# Out:
# 0.9128199957382306

# %%
df.isnull().sum()
# Out:
# X1    0
# X2    0
# X3    0
# X4    0
# X5    0
# dtype: int64

# %%
 import seaborn as sns
sns.boxplot(df['X4'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['X3'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['X2'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['X1'])
# Out:
# <Axes: >

# %%
Q1 = df.X4.quantile(0.25)
Q3 = df.X4.quantile(0.75)
Q1, Q3
# Out:
# (0.7130000000000001, 0.79525)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 0.08224999999999993

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (0.5896250000000002, 0.9186249999999999)

# %%
df[(df.X4<lower_limit)|(df.X4>upper_limit)]
# Out:
#      X1   X2     X3     X4    X5
# 17  7.6  225  0.425  0.571   3.3
# 22  6.4  210  0.475  0.244  13.6
# 39  7.0  245  0.407  0.573   3.2

# %%
df_no_outlier = df[(df.X4>lower_limit)&(df.X4<upper_limit)]
df_no_outlier
# Out:
#      X1   X2     X3     X4    X5
# 0   6.8  225  0.442  0.672   9.2
# 1   6.3  180  0.435  0.797  11.7
# 2   6.4  190  0.456  0.761  15.8
# 3   6.2  180  0.416  0.651   8.6
# 4   6.9  205  0.449  0.900  23.2
# 5   6.4  225  0.431  0.780  27.4
# 6   6.3  185  0.487  0.771   9.3
# 7   6.8  235  0.469  0.750  16.0
# 8   6.9  235  0.435  0.818   4.7
# 9   6.7  210  0.480  0.825  12.5
# 10  6.9  245  0.516  0.632  20.1
# 11  6.9  245  0.493  0.757   9.1
# 12  6.3  185  0.374  0.709   8.1
# 13  6.1  185  0.424  0.782   8.6
# 14  6.2  180  0.441  0.775  20.3
# 15  6.8  220  0.503  0.880  25.0
# 16  6.5  194  0.503  0.833  19.2
# 18  6.3  210  0.371  0.816  11.2
# 19  7.1  240  0.504  0.714  10.5
# 20  6.8  225  0.400  0.765  10.1
# 21  7.3  263  0.482  0.655   7.2
# 23  6.8  235  0.428  0.728   9.0
# 24  7.2  230  0.559  0.721  24.6
# 25  6.4  190  0.441  0.757  12.6
# 26  6.6  220  0.492  0.747   5.6
# 27  6.8  210  0.402  0.739   8.7
# 28  6.1  180  0.415  0.713   7.7
# 29  6.5  235  0.492  0.742  24.1
# 30  6.4  185  0.484  0.861  11.7
# 31  6.0  175  0.387  0.721   7.7
# 32  6.0  192  0.436  0.785   9.6
# 33  7.3  263  0.482  0.655   7.2
# 34  6.1  180  0.340  0.821  12.3
# 35  6.7  240  0.516  0.728   8.9
# 36  6.4  210  0.475  0.846  13.6
# 37  5.8  160  0.412  0.813  11.2
# 38  6.9  230  0.411  0.595   2.8
# 40  7.3  228  0.445  0.726   9.4
# 41  5.9  155  0.291  0.707  11.9
# 42  6.2  200  0.449  0.804  15.4
# 43  6.8  235  0.546  0.784   7.4
# 44  7.0  235  0.480  0.744  18.9
# 45  5.9  105  0.359  0.839   7.9
# 46  6.1  180  0.528  0.790  12.2
# 47  5.7  185  0.352  0.701  11.0
# 48  7.1  245  0.414  0.778   2.8
# 49  5.8  180  0.425  0.872  11.8
# 50  7.4  240  0.599  0.713  17.1
# 51  6.8  225  0.482  0.701  11.6
# 52  6.8  215  0.457  0.734   5.8
# 53  7.0  230  0.435  0.764   8.3

# %%
df_no_outlier.shape
# Out:
# (51, 5)

# %%
sns.boxplot(df_no_outlier['X4'])
# Out:
# <Axes: >

# %%
sns.boxplot(df_no_outlier['X1'])
# Out:
# <Axes: >

# %%
X = df_no_outlier.drop('X5',axis='columns')
X.head()
# Out:
#     X1   X2     X3     X4
# 0  6.8  225  0.442  0.672
# 1  6.3  180  0.435  0.797
# 2  6.4  190  0.456  0.761
# 3  6.2  180  0.416  0.651
# 4  6.9  205  0.449  0.900

# %%
Y= df_no_outlier['X5']
Y.head()
# Out:
# 0     9.2
# 1    11.7
# 2    15.8
# 3     8.6
# 4    23.2
# Name: X5, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.3)

# %%
X_train
# Out:
#      X1   X2     X3     X4
# 2   6.4  190  0.456  0.761
# 31  6.0  175  0.387  0.721
# 34  6.1  180  0.340  0.821
# 36  6.4  210  0.475  0.846
# 44  7.0  235  0.480  0.744
# 49  5.8  180  0.425  0.872
# 46  6.1  180  0.528  0.790
# 19  7.1  240  0.504  0.714
# 35  6.7  240  0.516  0.728
# 18  6.3  210  0.371  0.816
# 47  5.7  185  0.352  0.701
# 45  5.9  105  0.359  0.839
# 7   6.8  235  0.469  0.750
# 4   6.9  205  0.449  0.900
# 16  6.5  194  0.503  0.833
# 27  6.8  210  0.402  0.739
# 30  6.4  185  0.484  0.861
# 42  6.2  200  0.449  0.804
# 9   6.7  210  0.480  0.825
# 12  6.3  185  0.374  0.709
# 3   6.2  180  0.416  0.651
# 21  7.3  263  0.482  0.655
# 48  7.1  245  0.414  0.778
# 43  6.8  235  0.546  0.784
# 24  7.2  230  0.559  0.721
# 37  5.8  160  0.412  0.813
# 0   6.8  225  0.442  0.672
# 53  7.0  230  0.435  0.764
# 50  7.4  240  0.599  0.713
# 26  6.6  220  0.492  0.747
# 10  6.9  245  0.516  0.632
# 41  5.9  155  0.291  0.707
# 25  6.4  190  0.441  0.757
# 8   6.9  235  0.435  0.818
# 52  6.8  215  0.457  0.734

# %%
X_test
# Out:
#      X1   X2     X3     X4
# 6   6.3  185  0.487  0.771
# 20  6.8  225  0.400  0.765
# 29  6.5  235  0.492  0.742
# 38  6.9  230  0.411  0.595
# 32  6.0  192  0.436  0.785
# 13  6.1  185  0.424  0.782
# 15  6.8  220  0.503  0.880
# 5   6.4  225  0.431  0.780
# 11  6.9  245  0.493  0.757
# 28  6.1  180  0.415  0.713
# 40  7.3  228  0.445  0.726
# 23  6.8  235  0.428  0.728
# 51  6.8  225  0.482  0.701
# 33  7.3  263  0.482  0.655
# 1   6.3  180  0.435  0.797
# 14  6.2  180  0.441  0.775

# %%
y_train
# Out:
# 2     15.8
# 31     7.7
# 34    12.3
# 36    13.6
# 44    18.9
# 49    11.8
# 46    12.2
# 19    10.5
# 35     8.9
# 18    11.2
# 47    11.0
# 45     7.9
# 7     16.0
# 4     23.2
# 16    19.2
# 27     8.7
# 30    11.7
# 42    15.4
# 9     12.5
# 12     8.1
# 3      8.6
# 21     7.2
# 48     2.8
# 43     7.4
# 24    24.6
# 37    11.2
# 0      9.2
# 53     8.3
# 50    17.1
# 26     5.6
# 10    20.1
# 41    11.9
# 25    12.6
# 8      4.7
# 52     5.8
# Name: X5, dtype: float64

# %%
y_test
# Out:
# 6      9.3
# 20    10.1
# 29    24.1
# 38     2.8
# 32     9.6
# 13     8.6
# 15    25.0
# 5     27.4
# 11     9.1
# 28     7.7
# 40     9.4
# 23     9.0
# 51    11.6
# 33     7.2
# 1     11.7
# 14    20.3
# Name: X5, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      X1   X2     X3     X4
# 6   6.3  185  0.487  0.771
# 20  6.8  225  0.400  0.765
# 29  6.5  235  0.492  0.742
# 38  6.9  230  0.411  0.595
# 32  6.0  192  0.436  0.785
# 13  6.1  185  0.424  0.782
# 15  6.8  220  0.503  0.880
# 5   6.4  225  0.431  0.780
# 11  6.9  245  0.493  0.757
# 28  6.1  180  0.415  0.713
# 40  7.3  228  0.445  0.726
# 23  6.8  235  0.428  0.728
# 51  6.8  225  0.482  0.701
# 33  7.3  263  0.482  0.655
# 1   6.3  180  0.435  0.797
# 14  6.2  180  0.441  0.775

# %%
clf.predict(X_test)
# Out:
# array([13.95475796,  9.43725011, 11.64191997,  8.62342818, 11.34535022,
#        11.413548  , 14.20582662, 10.03263529, 11.88474469, 10.89678317,
#        11.45654479,  9.69184211, 12.00842517, 10.50607303, 12.49115228,
#        12.40794403])

# %%
y_test
# Out:
# 6      9.3
# 20    10.1
# 29    24.1
# 38     2.8
# 32     9.6
# 13     8.6
# 15    25.0
# 5     27.4
# 11     9.1
# 28     7.7
# 40     9.4
# 23     9.0
# 51    11.6
# 33     7.2
# 1     11.7
# 14    20.3
# Name: X5, dtype: float64

# %%
clf.score(X_test, y_test)
# Out:
# 0.07041837119329097

# %%
Y_pred = clf.predict(X_test)

# %%
from sklearn import metrics 
test_error_score = metrics.r2_score(y_test, Y_pred) 
print("R squared Error - Test: ", test_error_score)
# Out:
# R squared Error - Test:  0.07041837119329097

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.regplot(x=y_test, y=Y_pred, scatter_kws={"color": "green"}, line_kws={"color": "blue"})
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have the DataFrame df_no_outlier
# Extract features (X) and target (Y)
X = df_no_outlier.drop('X5', axis='columns').values
Y = df_no_outlier['X5'].values

# Normalize features (optional but can help with convergence)
X_normalized = (X - X.mean(axis=0)) / X.std(axis=0)

# Add a bias term to the features
X_normalized = np.column_stack((np.ones(X_normalized.shape[0]), X_normalized))

# Initialize weights
theta = np.zeros(X_normalized.shape[1])

# Hyperparameters
learning_rate = 0.01
iterations = 1000

# Gradient Descent
for _ in range(iterations):
    # Predictions
    predictions = np.dot(X_normalized, theta)
    
    # Errors
    errors = predictions - Y
    
    # Update weights
    gradient = np.dot(X_normalized.T, errors) / len(Y)
    theta -= learning_rate * gradient

# Print the learned coefficients
print("Learned Coefficients:")
print(theta)

# Plot the actual vs predicted points
plt.scatter(Y, predictions, c='blue', label='Actual vs Predicted')
plt.plot([min(Y), max(Y)], [min(Y), max(Y)], linestyle='--', color='red', linewidth=2, label='Ideal Line')
plt.xlabel('Actual Average Points')
plt.ylabel('Predicted Average Points')
plt.title('Actual vs Predicted Average Points')
plt.legend()
plt.show()
# Out:
# Learned Coefficients:
# [12.08967413 -0.83223988  0.2809369   2.19134873  1.54013045]
